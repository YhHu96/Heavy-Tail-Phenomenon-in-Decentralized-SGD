# %% [markdown]
# After you generate the .mat files containing the tail index for each layer of the neural network using decentralized SGD, you can run this code to plot tail index figures.

# %%
import os
import numpy as np
import scipy.io as sio

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 24 nodes; 16 batch-sizes

# %%
lr_list = ["0.02", "0.04", "0.06", "0.08", "0.1", "0.12", "0.14", "0.16", "0.18", "0.2"]
lr_array = np.arange(0.02,0.21,0.02)

# %%
# CSGD and DSGD with cycle
length = len(lr_list)
alphas_mc_CSGD_24n16b = np.zeros((length, 20))
alphas_mc_DSGD_24n16b = np.zeros((length, 20))

for i, lr in enumerate(lr_list):
    
    # spcify the path to your newly genearted .mat files
    filename_c = './24n16b/Cifar10_CSGD_24n16b_lr' + lr + '_20220217.mat'
    filename_d = './24n16b/Cifar10_DSGD_24n16b_lr' + lr + '_20220217.mat'
    print(filename_c)
    print(filename_d)
    mat_c = sio.loadmat(filename_c)
    mat_d = sio.loadmat(filename_d)
    alphas_mc_CSGD_24n16b[i] = mat_c['alphas_mc'].reshape(-1) 
    alphas_mc_DSGD_24n16b[i] = mat_d['alphas_mc'].reshape(-1)
# Out:
# ./24n16b/Cifar10_CSGD_24n16b_lr0.02_20220217.mat
# ./24n16b/Cifar10_DSGD_24n16b_lr0.02_20220217.mat
# ./24n16b/Cifar10_CSGD_24n16b_lr0.04_20220217.mat
# ./24n16b/Cifar10_DSGD_24n16b_lr0.04_20220217.mat
# ./24n16b/Cifar10_CSGD_24n16b_lr0.06_20220217.mat
# ./24n16b/Cifar10_DSGD_24n16b_lr0.06_20220217.mat
# ./24n16b/Cifar10_CSGD_24n16b_lr0.08_20220217.mat
# ./24n16b/Cifar10_DSGD_24n16b_lr0.08_20220217.mat
# ./24n16b/Cifar10_CSGD_24n16b_lr0.1_20220217.mat
# ./24n16b/Cifar10_DSGD_24n16b_lr0.1_20220217.mat
# ./24n16b/Cifar10_CSGD_24n16b_lr0.12_20220217.mat
# ./24n16b/Cifar10_DSGD_24n16b_lr0.12_20220217.mat
# ./24n16b/Cifar10_CSGD_24n16b_lr0.14_20220217.mat
# ./24n16b/Cifar10_DSGD_24n16b_lr0.14_20220217.mat
# ./24n16b/Cifar10_CSGD_24n16b_lr0.16_20220217.mat
# ./24n16b/Cifar10_DSGD_24n16b_lr0.16_20220217.mat
# ./24n16b/Cifar10_CSGD_24n16b_lr0.18_20220217.mat
# ./24n16b/Cifar10_DSGD_24n16b_lr0.18_20220217.mat
# ./24n16b/Cifar10_CSGD_24n16b_lr0.2_20220217.mat
# ...

# %%
# grid
length = len(lr_list)
alphas_mc_DSGD_24n16b_grid = np.zeros((length, 20))

for i, lr in enumerate(lr_list):
    
    filename_d = './24n16b/Cifar10_DSGDtopo_grid_24n16b_lr' + lr + '_20220221.mat'
    print(filename_d)
    mat_d = sio.loadmat(filename_d)
    alphas_mc_DSGD_24n16b_grid[i] = mat_d['alphas_mc'].reshape(-1)
# Out:
# ./24n16b/Cifar10_DSGDtopo_grid_24n16b_lr0.02_20220221.mat
# ./24n16b/Cifar10_DSGDtopo_grid_24n16b_lr0.04_20220221.mat
# ./24n16b/Cifar10_DSGDtopo_grid_24n16b_lr0.06_20220221.mat
# ./24n16b/Cifar10_DSGDtopo_grid_24n16b_lr0.08_20220221.mat
# ./24n16b/Cifar10_DSGDtopo_grid_24n16b_lr0.1_20220221.mat
# ./24n16b/Cifar10_DSGDtopo_grid_24n16b_lr0.12_20220221.mat
# ./24n16b/Cifar10_DSGDtopo_grid_24n16b_lr0.14_20220221.mat
# ./24n16b/Cifar10_DSGDtopo_grid_24n16b_lr0.16_20220221.mat
# ./24n16b/Cifar10_DSGDtopo_grid_24n16b_lr0.18_20220221.mat
# ./24n16b/Cifar10_DSGDtopo_grid_24n16b_lr0.2_20220221.mat

# %%
# star
length = len(lr_list)
alphas_mc_DSGD_24n16b_star = np.zeros((length, 20))

for i, lr in enumerate(lr_list):
    
    filename_d = './24n16b/Cifar10_DSGDtopo_star_24n16b_lr' + lr + '_20220221.mat'
    print(filename_d)
    mat_d = sio.loadmat(filename_d)
    alphas_mc_DSGD_24n16b_star[i] = mat_d['alphas_mc'].reshape(-1)
# Out:
# ./24n16b/Cifar10_DSGDtopo_star_24n16b_lr0.02_20220221.mat
# ./24n16b/Cifar10_DSGDtopo_star_24n16b_lr0.04_20220221.mat
# ./24n16b/Cifar10_DSGDtopo_star_24n16b_lr0.06_20220221.mat
# ./24n16b/Cifar10_DSGDtopo_star_24n16b_lr0.08_20220221.mat
# ./24n16b/Cifar10_DSGDtopo_star_24n16b_lr0.1_20220221.mat
# ./24n16b/Cifar10_DSGDtopo_star_24n16b_lr0.12_20220221.mat
# ./24n16b/Cifar10_DSGDtopo_star_24n16b_lr0.14_20220221.mat
# ./24n16b/Cifar10_DSGDtopo_star_24n16b_lr0.16_20220221.mat
# ./24n16b/Cifar10_DSGDtopo_star_24n16b_lr0.18_20220221.mat
# ./24n16b/Cifar10_DSGDtopo_star_24n16b_lr0.2_20220221.mat

# %%
# hypercube
length = len(lr_list)
alphas_mc_DSGD_24n16b_hypercube = np.zeros((length, 20))

for i, lr in enumerate(lr_list):
    
    filename_d = './24n16b/Cifar10_DSGDtopo_hypercube_24n16b_lr' + lr + '_20220223.mat'
    print(filename_d)
    mat_d = sio.loadmat(filename_d)
    alphas_mc_DSGD_24n16b_hypercube[i] = mat_d['alphas_mc'].reshape(-1)
# Out:
# ./24n16b/Cifar10_DSGDtopo_hypercube_24n16b_lr0.02_20220223.mat
# ./24n16b/Cifar10_DSGDtopo_hypercube_24n16b_lr0.04_20220223.mat
# ./24n16b/Cifar10_DSGDtopo_hypercube_24n16b_lr0.06_20220223.mat
# ./24n16b/Cifar10_DSGDtopo_hypercube_24n16b_lr0.08_20220223.mat
# ./24n16b/Cifar10_DSGDtopo_hypercube_24n16b_lr0.1_20220223.mat
# ./24n16b/Cifar10_DSGDtopo_hypercube_24n16b_lr0.12_20220223.mat
# ./24n16b/Cifar10_DSGDtopo_hypercube_24n16b_lr0.14_20220223.mat
# ./24n16b/Cifar10_DSGDtopo_hypercube_24n16b_lr0.16_20220223.mat
# ./24n16b/Cifar10_DSGDtopo_hypercube_24n16b_lr0.18_20220223.mat
# ./24n16b/Cifar10_DSGDtopo_hypercube_24n16b_lr0.2_20220223.mat

# %%
# fully
lr_list = ["0.02", "0.04", "0.06", "0.08", "0.1", "0.12", "0.14", "0.16", "0.18", "0.2"]
lr_array = np.arange(0.02,0.21,0.02)

length = len(lr_list)
alphas_mc_DSGD_24n16b_fully = np.zeros((length, 20))

for i, lr in enumerate(lr_list2):
    
    filename_d = './24n16b/Cifar10_DSGDtopo_fully_24n16b_lr' + lr + '_20220223.mat'
    print(filename_d)
    mat_d = sio.loadmat(filename_d)
    alphas_mc_DSGD_24n16b_fully[i] = mat_d['alphas_mc'].reshape(-1)
# Out:
# ./24n16b/Cifar10_DSGDtopo_fully_24n16b_lr0.02_20220223.mat
# ./24n16b/Cifar10_DSGDtopo_fully_24n16b_lr0.04_20220223.mat
# ./24n16b/Cifar10_DSGDtopo_fully_24n16b_lr0.06_20220223.mat
# ./24n16b/Cifar10_DSGDtopo_fully_24n16b_lr0.08_20220223.mat
# ./24n16b/Cifar10_DSGDtopo_fully_24n16b_lr0.1_20220223.mat
# ./24n16b/Cifar10_DSGDtopo_fully_24n16b_lr0.12_20220223.mat
# ./24n16b/Cifar10_DSGDtopo_fully_24n16b_lr0.14_20220223.mat

# %%
# use the median tail index of all 20 layers as the one to represent the nerual network 
CSGD_median = np.median(alphas_mc_CSGD_24n16b[:,1:19], axis = 1)
DSGD_median = np.median(alphas_mc_DSGD_24n16b[:,1:19], axis = 1)
Grid_median = np.median(alphas_mc_DSGD_24n16b_grid[:,1:19], axis = 1)
Star_median = np.median(alphas_mc_DSGD_24n16b_star[:,1:19], axis = 1)
Hyper_median = np.median(alphas_mc_DSGD_24n16b_hypercube[:,1:19], axis = 1)
Fully_median = np.median(alphas_mc_DSGD_24n16b_fully[:,1:19], axis = 1)
Disconnected_median = np.median(alphas_mc_DSGD_24n16b_disconnected[:,1:19], axis = 1)

# %%
fig=plt.figure(figsize=(10,7.5))
plt.plot(lr_array, Fully_median, 'b-', lr_array, DSGD_median, 'r-', \
         lr_array, Star_median, 'm-', lr_array, Hyper_median, 'c-', \
         lr_array2, Disconnected_median, 'y-', lr_array, CSGD_median, 'g-', linewidth=3)
plt.legend(['Complete','Cycle','Star','HyperCube', 'Dis-SGD', 'C-SGD'], loc='best', fontsize = 23)
plt.xlabel(r'Stepsize $\eta$',fontsize=25)
plt.ylabel(r'Tail index $\alpha$',fontsize=25)
plt.tick_params(labelsize=25)
